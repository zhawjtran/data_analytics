# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
from pandas import json_normalize
import requests
import json
import folium

# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3392, 237)
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225069  8.969981       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.source:addr tags.opening_date tags.postid tags.operator:website  \
# 0              NaN               NaN         NaN                   NaN
# 1              NaN               NaN         NaN                   NaN
# 2              NaN               NaN         NaN                   NaN
# 3              NaN               NaN         NaN                   NaN
# 4              NaN               NaN         NaN                   NaN
#
#   tags.diet:local tags.payment:account_cards tags.diet:fish  \
# 0             NaN                        NaN            NaN
# 1             NaN                        NaN            NaN
# 2             NaN                        NaN            NaN
# 3             NaN                        NaN            NaN
# 4             NaN                        NaN            NaN
#
#   tags.diet:mediterranean tags.diet:organic tags.diet:seafood
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
# [5 rows x 237 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225069  8.969981       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_effbb2c661e5b21c1fdb26feabd08f4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_effbb2c661e5b21c1fdb26feabd08f4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_effbb2c661e5b21c1fdb26feabd08f4b = L.map(
#                 &quot;map_effbb2c661e5b21c1fdb26feabd08f4b&quot;,
#                 {
#                     center: [47.009678141875, 7.990980280625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_effbb2c661e5b21c1fdb26feabd08f4b);
#
#
#
#
#
#             var tile_layer_ad7f439d62ced07140aec53b787d215d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_effbb2c661e5b21c1fdb26feabd08f4b);
#
#
#             var marker_afd96ee38f754bc542fd21ae84d0e01c = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_effbb2c661e5b21c1fdb26feabd08f4b);
#
#
#         var popup_d48f4256de5d750fd215f3f3e55c4807 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b991ac6680158cb36953e409a9535ce6 = $(`&lt;div id=&quot;html_b991ac6680158cb36953e409a9535ce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_d48f4256de5d750fd215f3f3e55c4807.setContent(html_b991ac6680158cb36953e409a9535ce6);
#
#
#
#         marker_afd96ee38f754bc542fd21ae84d0e01c.bindPopup(popup_d48f4256de5d750fd215f3f3e55c4807)
#         ;
#
#
#
#
#             var marker_d77dcb53cb1baae465b062331d099542 = L.marker(
#                 [47.2250689, 8.9699805],
#                 {}
#             ).addTo(map_effbb2c661e5b21c1fdb26feabd08f4b);
#
#
#         var popup_8ece63843215ed4feb70f62007ab422d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7245615e9a15a4f75d3b2abcc9bb6695 = $(`&lt;div id=&quot;html_7245615e9a15a4f75d3b2abcc9bb6695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_8ece63843215ed4feb70f62007ab422d.setContent(html_7245615e9a15a4f75d3b2abcc9bb6695);
#
#
#
#         marker_d77dcb53cb1baae465b062331d099542.bindPopup(popup_8ece63843215ed4feb70f62007ab422d)
#         ;
#
#
#
#
#             var marker_c18687085ac16f704ffd96cd9f74a78a = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_effbb2c661e5b21c1fdb26feabd08f4b);
#
#
#         var popup_d5c7be91d2c1fd65db27353051bf0868 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23a1790fc8e7981e73f37a7b5a58dd20 = $(`&lt;div id=&quot;html_23a1790fc8e7981e73f37a7b5a58dd20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_d5c7be91d2c1fd65db27353051bf0868.setContent(html_23a1790fc8e7981e73f37a7b5a58dd20);
#
#
#
#         marker_c18687085ac16f704ffd96cd9f74a78a.bindPopup(popup_d5c7be91d2c1fd65db27353051bf0868)
#         ;
#
#
#
#
#             var marker_a413bf20a0fc9284874032f71a7e4c95 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_effbb2c661e5b21c1fdb26feabd08f4b);
#
#
#         var popup_c0a972da1b0c5de631438e58a8612734 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a74af7687fa6fe2e0fb9b8151b1fe51b = $(`&lt;div id=&quot;html_a74af7687fa6fe2e0fb9b8151b1fe51b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_c0a972da1b0c5de631438e58a8612734.setContent(html_a74af7687fa6fe2e0fb9b8151b1fe51b);
#
#
#
#         marker_a413bf20a0fc9284874032f71a7e4c95.bindPopup(popup_c0a972da1b0c5de631438e58a8612734)
#         ;
#
#
#
#
#             var marker_a31435fd6f2717498d6aa046e18d1185 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_effbb2c661e5b21c1fdb26feabd08f4b);
#
#
#         var popup_f6f77bf09704a0a27ba3117bc49cd316 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2eb646a03709d5fbc759bfa3cacfa51 = $(`&lt;div id=&quot;html_a2eb646a03709d5fbc759bfa3cacfa51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_f6f77bf09704a0a27ba3117bc49cd316.setContent(html_a2eb646a03709d5fbc759bfa3cacfa51);
#
#
#
#         marker_a31435fd6f2717498d6aa046e18d1185.bindPopup(popup_f6f77bf09704a0a27ba3117bc49cd316)
#         ;
#
#
#
#
#             var marker_aa304a7a2a8c14829bce56b30edcad79 = L.marker(

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2023-08-24 10:22:12
# Python Version: 3.10.12
# -----------------------------------
