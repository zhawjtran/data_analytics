# %% [markdown]
# # Population and samples in statistics

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import numpy as np
import random
import statistics
import matplotlib.pyplot as plt
from IPython.display import Image

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /Users/john/School/Sem5/DA/data_analytics/Week_06

# %% [markdown]
# # Chickens on a chicken farm (simulated data)

# %%
Image("chickens.png", width=800)

# %%
# Parameters of distribution
p_mean = 2800
p_std = 240
p_n = 25000

# Setting a seed to restore the random numbers later
random.seed(42)

# Generate (normally distributed) data with mean = 2800 g and standard deviation = 240 g
pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)
print(f'{len(pop):.0f}')
print(f'{np.mean(pop):.4f}')
print(f'{np.std(pop):.4f}')

# Plot histogram based on the data
plt.hist(pop, bins = 50, color='gold')
plt.title('Weight of chickens (simulated data)')
plt.xlabel('Weight (grams)')
plt.ylabel('Number of chickens')

plt.show()
# Out:
# 25000
# 2800.3897
# 237.9660

# %% [markdown]
# ## Single random sample from the population

# %%
# Sample size
sample_size = 200

# Setting a seed to restore the random numbers later
random.seed(42)

# Random sample
random_sample = random.sample(list(pop), sample_size)

# Statistics of the sample
print(f'Mean: {statistics.mean(random_sample):.4f}')
print(f'Standard deviation: {statistics.stdev(random_sample):.4f}')

# Plot histogram based on the sample
plt.hist(random_sample, bins = 50, color='deepskyblue')
plt.title(f'Weights of chickens (single sample with n={sample_size})', fontsize=10)
plt.xlabel('Weight (grams)')
plt.ylabel('Number of chickens')

plt.show()
# Out:
# Mean: 2798.4401
# Standard deviation: 260.8509

# %% [markdown]
# ## Repeated random sampling 'with replacement' (bootstrapping)

# %%
def bootstrap(p_mean= 2800, p_std= 240, num_iter = 5000, sample_size = 200):
    """
    Creates bootstrap sample from a distribution.

    :param p_mean population mean. Type = int, float
    :param p_std. Type = int, float
    :param p_n. Type = int, float
    :param num_iterations: number of iterations. Type = int
    :param sample_size: size of single bootstrap sample. Type = int
    :return: plot of bootstrap sample.
    """

    # Setting a seed to restore the random numbers later
    random.seed(42)

    # Generate (normally distributed) data
    pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)

    # Create empty lists to save results of iterations
    sample_mean = []
    sample_std  = []

    # Loop for iterations
    for i in range(num_iter):
        samp = random.sample(pop.tolist(), sample_size)
        avg = np.mean(samp)
        std = np.std(samp)
        sample_mean.append(avg)
        sample_std.append(std)

    # Print mean and sd of bootsstapped distribution
    print(f'{np.mean(sample_mean):.4f}')
    print(f'{np.mean(sample_std):.4f}')

    # Plot histogram based on the bootstrapped data
    plt.hist(sample_mean, bins = 50, color='mediumorchid')
    plt.title('Weights of chickens (bootstrap sample)', fontsize=10)
    plt.xlabel('Weight (grams)')
    plt.ylabel('Number of chickens')
    plt.show()

# Function call
bootstrap(p_mean=180, p_std=25, num_iter = 1000, sample_size = 1000)
# Out:
# 179.9306
# 24.8240

# %% [markdown]
# # Own example - Trees in a forest (simulated data)

# %%
from PIL import Image
from IPython.display import display

# Öffnen Sie das Bild
original_image = Image.open("forest.jpeg")

# Neue Größe festlegen (Breite x Höhe)
new_size = (800, 200)

# Bildgröße ändern
resized_image = original_image.resize(new_size)

# Das Bild anzeigen
display(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x200>

# %%
# Parameters of distribution
p_mean = 60
p_std = 10
p_n = 25000

# Setting a seed to restore the random numbers later
random.seed(42)

# Generate (normally distributed) data with mean = 60 cm and standard deviation = 10 cm 
pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)
print(f'{len(pop):.0f}')
print(f'{np.mean(pop):.4f}')
print(f'{np.std(pop):.4f}')

# Plot histogram based on the data
plt.hist(pop, bins = 50, color='gold')
plt.title('Diameters of Trees (simulated data)')
plt.xlabel('Diameters (cm)')
plt.ylabel('Number of Trees')

plt.show()
# Out:
# 25000
# 59.8899
# 9.9614

# %% [markdown]
# ## Single random sample from the population

# %%
# Sample size
sample_size = 200

# Setting a seed to restore the random numbers later
random.seed(42)

# Random sample
random_sample = random.sample(list(pop), sample_size)

# Statistics of the sample
print(f'Mean: {statistics.mean(random_sample):.4f}')
print(f'Standard deviation: {statistics.stdev(random_sample):.4f}')

# Plot histogram based on the sample
plt.hist(random_sample, bins = 50, color='deepskyblue')
plt.title(f'Diameters of Trees (single sample with n={sample_size})', fontsize=10)
plt.xlabel('Diameters (grams)')
plt.ylabel('Number of Trees')

plt.show()
# Out:
# Mean: 59.9044
# Standard deviation: 9.2368

# %% [markdown]
# ## Repeated random sampling 'with replacement' (bootstrapping)

# %%
def bootstrap(p_mean= 60, p_std= 10, num_iter = 5000, sample_size = 200):
    """
    Creates bootstrap sample from a distribution.

    :param p_mean population mean. Type = int, float (Mittelwert der Population)
    :param p_std. Type = int, float (Standardabweichung der Population)
    :param p_n. Type = int, float (Anzahl der Elemente in der Population)
    :param num_iterations: number of iterations. Type = int (Anzahl der Iterationen)
    :param sample_size: size of single bootstrap sample. Type = int (Größe der einzelnen Bootstrap-Stichprobe)
    :return: plot of bootstrap sample.
    """

    # Setting a seed to restore the random numbers later
    random.seed(42)

    # Generate (normally distributed) data
    pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)

    # Create empty lists to save results of iterations
    sample_mean = []
    sample_std  = []

    # Loop for iterations
    for i in range(num_iter):
        samp = random.sample(pop.tolist(), sample_size)
        avg = np.mean(samp)
        std = np.std(samp)
        sample_mean.append(avg)
        sample_std.append(std)

    # Print mean and sd of bootsstapped distribution
    print(f'{np.mean(sample_mean):.4f}')
    print(f'{np.mean(sample_std):.4f}')

    # Plot histogram based on the bootstrapped data
    plt.hist(sample_mean, bins = 50, color='mediumorchid')
    plt.title('Diameters of Trees (bootstrap sample)', fontsize=10)
    plt.xlabel('Diameters (grams)')
    plt.ylabel('Number of Trees')
    plt.show()

# Function call
bootstrap(p_mean=60, p_std=10, num_iter = 1000, sample_size = 1000)
# Out:
# 60.1060
# 10.0866

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Darwin | 23.0.0
# Datetime: 2023-11-01 15:03:33
# Python Version: 3.9.6
# -----------------------------------
