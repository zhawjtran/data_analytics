# %% [markdown]
# # Additional OpenStreetMap examples

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import json
import requests
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Current working directory
print('Current working directory:', os.getcwd())
# Out:
# Current working directory: U:\Lektionen\DA_HS2022\KK\Week_13

# %% [markdown]
# ## Overpass turbo query cinemas in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""[out:json][timeout:25];
            area["ISO3166-1"="CH"][admin_level=2];
            (
              node["amenity"="cinema"](area);
              way["amenity"="cinema"](area);
              relation["amenity"="cinema"](area);
            );
            out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('cinemas.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df_cinemas = json_normalize(data)
df_cinemas.head(5)
# Out:
#    type         id        lat       lon tags.addr:housenumber  \
# 0  node    1014954  46.492849  7.562856                    18
# 1  node   29455086  47.498779  8.726124                    13
# 2  node  213230419  46.684335  7.855911                   NaN
# 3  node  245455175  47.474872  8.307535                    22
# 4  node  247696793  47.657373  8.858442                   NaN
#
#   tags.addr:street tags.amenity   tags.name         tags.url  \
# 0      Landstrasse       cinema    Ciné Rex  www.cine-rex.ch
# 1         Neumarkt       cinema        Kiwi              NaN
# 2              NaN       cinema    Cine Rex              NaN
# 3   Bahnhofstrasse       cinema  Kino Sterk              NaN
# 4              NaN       cinema    Schwanen              NaN
#
#                          tags.website  ... tags.wardrobe tags.wardrobe:level  \
# 0  https://www.cine-rex.ch/kino.shtml  ...           NaN                 NaN
# 1                                 NaN  ...           NaN                 NaN
# 2      http://www.kino-interlaken.ch/  ...           NaN                 NaN
# 3               https://www.sterk.ch/  ...           NaN                 NaN
# 4                                 NaN  ...           NaN                 NaN
#
#   tags.name:de tags.addr:street:de tags.internet_access tags.air_conditioning  \
# 0          NaN                 NaN                  NaN                   NaN
# 1          NaN                 NaN                  NaN                   NaN
# 2          NaN                 NaN                  NaN                   NaN
# 3          NaN                 NaN                  NaN                   NaN
# 4          NaN                 NaN                  NaN                   NaN
#
#   tags.opening_hours:covid19 tags.brand:wikidata tags.branch tags.location
# 0                        NaN                 NaN         NaN           NaN
# 1                        NaN                 NaN         NaN           NaN
# 2                        NaN                 NaN         NaN           NaN
# 3                        NaN                 NaN         NaN           NaN
# 4                        NaN                 NaN         NaN           NaN
#
# [5 rows x 99 columns]

# %% [markdown]
# ## Plot cinemas on map

# %%
# Marker symbol
icon = 'https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-red.png'

# Create map
map = folium.Map(location=[df_cinemas.lat.mean(), 
                           df_cinemas.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in df_cinemas.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                   popup=location_info["tags.name"],
                   icon=folium.features.CustomIcon(icon,icon_size=(16, 26))).add_to(map)

# Plot map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19db7b7e51c84b19bb0950bc7eb26480 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19db7b7e51c84b19bb0950bc7eb26480&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_19db7b7e51c84b19bb0950bc7eb26480 = L.map(
#                 &quot;map_19db7b7e51c84b19bb0950bc7eb26480&quot;,
#                 {
#                     center: [46.92859461347827, 7.79613568],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_19db7b7e51c84b19bb0950bc7eb26480);
#
#
#
#
#
#             var tile_layer_f422bc756070afb64e539be1685e153a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19db7b7e51c84b19bb0950bc7eb26480);
#
#
#             var marker_c005520593d1139d675f5d82ebcccca3 = L.marker(
#                 [46.4928487, 7.5628558],
#                 {}
#             ).addTo(map_19db7b7e51c84b19bb0950bc7eb26480);
#
#
#         var custom_icon_560fb2c688d0714cb94e45a64f4ffca1 = L.icon({&quot;iconSize&quot;: [16, 26], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-red.png&quot;});
#         marker_c005520593d1139d675f5d82ebcccca3.setIcon(custom_icon_560fb2c688d0714cb94e45a64f4ffca1);
#
#
#         var popup_760de824ab80a3c36f8cf83f44baa2c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1c5eb45197eec7f7034dc3b38887faa9 = $(`&lt;div id=&quot;html_1c5eb45197eec7f7034dc3b38887faa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ciné Rex&lt;/div&gt;`)[0];
#             popup_760de824ab80a3c36f8cf83f44baa2c8.setContent(html_1c5eb45197eec7f7034dc3b38887faa9);
#
#
#         marker_c005520593d1139d675f5d82ebcccca3.bindPopup(popup_760de824ab80a3c36f8cf83f44baa2c8)
#         ;
#
#
#
#
#             var marker_f711b00c42322d20ed3dd4dc6e9a3423 = L.marker(
#                 [47.4987786, 8.7261242],
#                 {}
#             ).addTo(map_19db7b7e51c84b19bb0950bc7eb26480);
#
#
#         var custom_icon_b079a3b7fc1757d9346defc7bc8b82f5 = L.icon({&quot;iconSize&quot;: [16, 26], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-red.png&quot;});
#         marker_f711b00c42322d20ed3dd4dc6e9a3423.setIcon(custom_icon_b079a3b7fc1757d9346defc7bc8b82f5);
#
#
#         var popup_bef10019bfc99b486132b589a7df96ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7bd9b3011760f25376436aaff5e58255 = $(`&lt;div id=&quot;html_7bd9b3011760f25376436aaff5e58255&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kiwi&lt;/div&gt;`)[0];
#             popup_bef10019bfc99b486132b589a7df96ec.setContent(html_7bd9b3011760f25376436aaff5e58255);
#
#
#         marker_f711b00c42322d20ed3dd4dc6e9a3423.bindPopup(popup_bef10019bfc99b486132b589a7df96ec)
#         ;
#
#
#
#
#             var marker_a13d6b37cecf87ef90f8b5dafcfccb03 = L.marker(
#                 [46.6843354, 7.8559108],
#                 {}
#             ).addTo(map_19db7b7e51c84b19bb0950bc7eb26480);
#
#
#         var custom_icon_9a51ac32b3a9dc11331098662c07d764 = L.icon({&quot;iconSize&quot;: [16, 26], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-red.png&quot;});
#         marker_a13d6b37cecf87ef90f8b5dafcfccb03.setIcon(custom_icon_9a51ac32b3a9dc11331098662c07d764);
#
#
#         var popup_3bef65d28ddbbd7a28c94f28d43b5e44 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2e7ec4de3cd9b5e6cab8feba4988b8a0 = $(`&lt;div id=&quot;html_2e7ec4de3cd9b5e6cab8feba4988b8a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cine Rex&lt;/div&gt;`)[0];
#             popup_3bef65d28ddbbd7a28c94f28d43b5e44.setContent(html_2e7ec4de3cd9b5e6cab8feba4988b8a0);
#
#
#         marker_a13d6b37cecf87ef90f8b5dafcfccb03.bindPopup(popup_3bef65d28ddbbd7a28c94f28d43b5e44)
#         ;
#
#
#
#
#             var marker_15a8e54f58fb5f633634037241c8fe45 = L.marker(
#                 [47.4748718, 8.3075346],
#                 {}
#             ).addTo(map_19db7b7e51c84b19bb0950bc7eb26480);
#
#
#         var custom_icon_e833c776470c97589691829291f6ed0b = L.icon({&quot;iconSize&quot;: [16, 26], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-red.png&quot;});
#         marker_15a8e54f58fb5f633634037241c8fe45.setIcon(custom_icon_e833c776470c97589691829291f6ed0b);
#
#
#         var popup_f03704868c98694850d083ece8d2cdd2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_58673fca8b3d5587c33c704b4249748a = $(`&lt;div id=&quot;html_58673fca8b3d5587c33c704b4249748a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kino S

# %% [markdown]
# ## Overpass turbo query pharmacies

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""[out:json][timeout:25];
            area["ISO3166-1"="CH"][admin_level=2];
            (
              node["amenity"="pharmacy"](area);
              way["amenity"="pharmacy"](area);
              relation["amenity"="pharmacy"](area);
            );
            out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('pharmacy.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df_pharmacy = json_normalize(data)
df_pharmacy.head(5)
# Out:
#    type         id        lat       lon tags.addr:city tags.addr:housenumber  \
# 0  node   75757805  47.240975  8.726228          Stäfa                     4
# 1  node  132405322  47.520987  8.540215         Bülach                    28
# 2  node  244444037  46.787960  6.620956            NaN                   NaN
# 3  node  246249851  47.491757  8.706065     Winterthur                   102
# 4  node  246249855  47.499028  8.724259     Winterthur                    39
#
#   tags.addr:postcode tags.addr:street tags.amenity tags.brand  ...  \
# 0               8712     Grundstrasse     pharmacy     Fortis  ...
# 1               8180   Bahnhofstrasse     pharmacy    Amavita  ...
# 2                NaN              NaN     pharmacy        NaN  ...
# 3               8406   Zürcherstrasse     pharmacy    Medbase  ...
# 4               8400         Untertor     pharmacy        NaN  ...
#
#   tags.indoor tags.name:it tags.network tags.addr:city:de tags.addr:city:fr  \
# 0         NaN          NaN          NaN               NaN               NaN
# 1         NaN          NaN          NaN               NaN               NaN
# 2         NaN          NaN          NaN               NaN               NaN
# 3         NaN          NaN          NaN               NaN               NaN
# 4         NaN          NaN          NaN               NaN               NaN
#
#   tags.building tags.payment:cards tags.contact:whatsapp tags.level:ref  \
# 0           NaN                NaN                   NaN            NaN
# 1           NaN                NaN                   NaN            NaN
# 2           NaN                NaN                   NaN            NaN
# 3           NaN                NaN                   NaN            NaN
# 4           NaN                NaN                   NaN            NaN
#
#   tags.wikidata
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 123 columns]

# %% [markdown]
# ## Plot pharmacies on map

# %%
# Marker symbol
icon = 'https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png'

# Create map
map = folium.Map(location=[df_pharmacy.lat.mean(), 
                           df_pharmacy.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in df_pharmacy.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                   popup=location_info["tags.name"],
                   icon=folium.features.CustomIcon(icon,icon_size=(16, 26))).add_to(map)

# Plot map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d977e2d213025265d831f8758284c573 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d977e2d213025265d831f8758284c573&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d977e2d213025265d831f8758284c573 = L.map(
#                 &quot;map_d977e2d213025265d831f8758284c573&quot;,
#                 {
#                     center: [46.87861248735484, 7.774602374258064],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d977e2d213025265d831f8758284c573);
#
#
#
#
#
#             var tile_layer_c7e0d3346fd5787ca72d7e05248233fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d977e2d213025265d831f8758284c573);
#
#
#             var marker_7fc741a3c08e995b042adab44d123c39 = L.marker(
#                 [47.2409751, 8.7262277],
#                 {}
#             ).addTo(map_d977e2d213025265d831f8758284c573);
#
#
#         var custom_icon_d41794760374b22de7fbd24795307933 = L.icon({&quot;iconSize&quot;: [16, 26], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_7fc741a3c08e995b042adab44d123c39.setIcon(custom_icon_d41794760374b22de7fbd24795307933);
#
#
#         var popup_b0998cfc1c9a69ba5edf1e00eb765bd9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e1192a20bfb5645193c5d09b6d85c0f7 = $(`&lt;div id=&quot;html_e1192a20bfb5645193c5d09b6d85c0f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Apotheke zum Rebstock&lt;/div&gt;`)[0];
#             popup_b0998cfc1c9a69ba5edf1e00eb765bd9.setContent(html_e1192a20bfb5645193c5d09b6d85c0f7);
#
#
#         marker_7fc741a3c08e995b042adab44d123c39.bindPopup(popup_b0998cfc1c9a69ba5edf1e00eb765bd9)
#         ;
#
#
#
#
#             var marker_8fe1e0aaab410f3a87a47805cfbbb0d3 = L.marker(
#                 [47.520987, 8.540215],
#                 {}
#             ).addTo(map_d977e2d213025265d831f8758284c573);
#
#
#         var custom_icon_47e153c5eeacc2f3d60ad9030d7573f0 = L.icon({&quot;iconSize&quot;: [16, 26], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_8fe1e0aaab410f3a87a47805cfbbb0d3.setIcon(custom_icon_47e153c5eeacc2f3d60ad9030d7573f0);
#
#
#         var popup_c6442df7bec351f4b877b7c04df13121 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_57266a631190c0a4d5093aa226928800 = $(`&lt;div id=&quot;html_57266a631190c0a4d5093aa226928800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amavita&lt;/div&gt;`)[0];
#             popup_c6442df7bec351f4b877b7c04df13121.setContent(html_57266a631190c0a4d5093aa226928800);
#
#
#         marker_8fe1e0aaab410f3a87a47805cfbbb0d3.bindPopup(popup_c6442df7bec351f4b877b7c04df13121)
#         ;
#
#
#
#
#             var marker_004ae4f7a9ed0097729494200b7907a5 = L.marker(
#                 [46.7879597, 6.620956],
#                 {}
#             ).addTo(map_d977e2d213025265d831f8758284c573);
#
#
#         var custom_icon_6740930793fbf480b02ac5cc76db3dbf = L.icon({&quot;iconSize&quot;: [16, 26], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_004ae4f7a9ed0097729494200b7907a5.setIcon(custom_icon_6740930793fbf480b02ac5cc76db3dbf);
#
#
#         var popup_16605d20cbd0d0b6aeb811d4545f0853 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1b70ca1eb5faef20312164fe17d1206d = $(`&lt;div id=&quot;html_1b70ca1eb5faef20312164fe17d1206d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SunStore&lt;/div&gt;`)[0];
#             popup_16605d20cbd0d0b6aeb811d4545f0853.setContent(html_1b70ca1eb5faef20312164fe17d1206d);
#
#
#         marker_004ae4f7a9ed0097729494200b7907a5.bindPopup(popup_16605d20cbd0d0b6aeb811d4545f0853)
#         ;
#
#
#
#
#             var marker_435bc97222045cb2570919936d830b13 = L.marker(
#                 [47.4917575, 8.7060655],
#                 {}
#             ).addTo(map_d977e2d213025265d831f8758284c573);
#
#
#         var custom_icon_cf24972f141a7f8f700bb18017a34fd2 = L.icon({&quot;iconSize&quot;: [16, 26], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_435bc97222045cb2570919936d830b13.setIcon(custom_icon_cf24972f141a7f8f700bb18017a34fd2);
#
#
#         var popup_0d425c6d6d99471339965e73604eb3b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_03182e82921a6102f681bef21e57ebca = $(`&lt;div id=&quot;html_03182e82921a6102f681bef21e57ebca&quot; style=&quot;width: 100.0%; hei
